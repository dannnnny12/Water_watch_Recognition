# %%
from matplotlib.pyplot import imshow
# %matplotlib inline
from turtle import clone
import cv2 as cv2
import numpy as np
path = ("./changed.jpg")
m = cv2.imread(path)
gray = cv2.cvtColor(m,cv2.COLOR_BGR2GRAY)

blurred = cv2.GaussianBlur(gray, (5,5),0) #高斯模糊
imshow(blurred)
edged = cv2.Canny(blurred, 200,250) #邊緣萃取

contours, hierarchy = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
clone = m.copy()
if clone is None:
    print("null")
n = cv2.drawContours(clone,contours,-1, (0,255,0),2)

x,y,w,h = cv2.boundingRect(contours[0])
cv2.rectangle(m,(x,y),(x+w,y+h),(153,153,0),5)
newimage = m[y+2:y+h-2, x+2:x+w-2]
if newimage is None:
    print("null")
reimg = cv2.resize(clone, (467,601))
hsv =cv2.cvtColor(reimg, cv2.COLOR_BGR2HSV)

lower_red = np.array([0,100,100])
upper_red = np.array([20,255,255])
mask = cv2.inRange(hsv, lower_red, upper_red)

output = cv2.bitwise_and(hsv,hsv,mask = mask)

coordinate = output[375,233]
#print(coordinate)
a = np.array(coordinate)
#print(a)
b = np.array(output)
#print(a.size)
#print(b.size)
#print(b)
#cv2.imshow(reimg)
if ((a==[0,255,255]).all()):
    print("It is moistened")
else:
    print("it is not moistened")
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# It is moistened

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\danny\appdata\local\programs\python\python310\lib\site-packages (3.6.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\danny\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\danny\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\danny\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\danny\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\danny\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.37.4)
# Requirement already satisfied: numpy>=1.19 in c:\users\danny\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.23.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\danny\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\danny\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\danny\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\danny\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.14.0)
# Note: you may need to restart the kernel to use updated packages.
